# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pizza types/cheese/Image_1.jpg')
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_img)
plt.axis('off')
plt.show()
