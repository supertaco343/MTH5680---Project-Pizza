# %% [markdown]
# # Libraries

# %% [markdown]
# ### For CNN

# %%
from keras.layers import Rescaling
from keras.models import Sequential
from keras.utils import image_dataset_from_directory
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %% [markdown]
# ### For KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Utilities

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from data_cleanup import clean_data
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Setup

# %%
data_dir = 'pizza types'

# %%
# Converting all files to .jpg and resizing them to 256x256
clean_data(data_dir)

# %% [markdown]
# # KNN

# %%
def train_test_split_from_directory(data_dir):
    X_train, X_test, y_train, y_test = [], [], [], []

    for subdir in os.listdir(data_dir):
        subdir_path = os.path.join(data_dir, subdir)
        X_subdir, y_subdir = [], []

        for filename in os.listdir(subdir_path):
            img = cv2.cvtColor(cv2.imread(os.path.join(subdir_path, filename)), cv2.COLOR_BGR2RGB)
            X_subdir.append(img)
            y_subdir.append(subdir)
        
        X_train_subdir, X_test_subdir, y_train_subdir, y_test_subdir = train_test_split(X_subdir, y_subdir, test_size=0.2, random_state=42)

        X_train.extend(X_train_subdir)
        X_test.extend(X_test_subdir)
        y_train.extend(y_train_subdir)
        y_test.extend(y_test_subdir)
        
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split_from_directory(data_dir)

# %%
def shuffle_data(data, seed):
    rng = np.random.default_rng(seed)
    shuffled_indices = rng.permutation(len(data))
    return [data[i] for i in shuffled_indices]

# %%
seed = 42
X_train = shuffle_data(X_train, seed)
X_test = shuffle_data(X_test, seed)
y_train = shuffle_data(y_train, seed)
y_test = shuffle_data(y_test, seed)

# %%
X_train = np.reshape(X_train, (len(y_train), -1))
X_test = np.reshape(X_test, (len(y_test), -1))

# %%
label_encoder = LabelEncoder()

y_test = label_encoder.fit_transform(y_test)
y_train = label_encoder.fit_transform(y_train)

# %%
max_testing_accuracy = 0
for k in range(1, 394, 5): 
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    if accuracy_score(y_test, y_test_pred) > max_testing_accuracy:
        max_testing_accuracy = accuracy_score(y_test, y_test_pred)

    print('For k =', k)
    print('Train Data Accuracy:', accuracy_score(y_train, y_train_pred))
    print()
    print('Test Data Accuracy:', accuracy_score(y_test, y_test_pred))
    print()
print(max_testing_accuracy)
# Out:
# For k = 1
# Train Data Accuracy: 1.0
#
# Test Data Accuracy: 0.40594059405940597
#
# For k = 6
# Train Data Accuracy: 0.44472361809045224
#
# Test Data Accuracy: 0.31683168316831684
#
# For k = 11
# Train Data Accuracy: 0.42462311557788945
#
# Test Data Accuracy: 0.2871287128712871
#
# For k = 16
# Train Data Accuracy: 0.40954773869346733
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 21
# Train Data Accuracy: 0.3869346733668342
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 26
# Train Data Accuracy: 0.38944723618090454
#
# Test Data Accuracy: 0.297029702970297
#
# For k = 31
# Train Data Accuracy: 0.3768844221105528
#
# Test Data Accuracy: 0.297029702970297
#
# For k = 36
# Train Data Accuracy: 0.3743718592964824
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 41
# Train Data Accuracy: 0.3592964824120603
#
# Test Data Accuracy: 0.37623762376237624
#
# For k = 46
# Train Data Accuracy: 0.3592964824120603
#
# Test Data Accuracy: 0.32673267326732675
#
# For k = 51
# Train Data Accuracy: 0.35678391959798994
#
# Test Data Accuracy: 0.31683168316831684
#
# For k = 56
# Train Data Accuracy: 0.3492462311557789
#
# Test Data Accuracy: 0.32673267326732675
#
# For k = 61
# Train Data Accuracy: 0.3417085427135678
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 66
# Train Data Accuracy: 0.3417085427135678
#
# Test Data Accuracy: 0.31683168316831684
#
# For k = 71
# Train Data Accuracy: 0.3341708542713568
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 76
# Train Data Accuracy: 0.32160804020100503
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 81
# Train Data Accuracy: 0.30402010050251255
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 86
# Train Data Accuracy: 0.2964824120603015
#
# Test Data Accuracy: 0.38613861386138615
#
# For k = 91
# Train Data Accuracy: 0.3165829145728643
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 96
# Train Data Accuracy: 0.3165829145728643
#
# Test Data Accuracy: 0.32673267326732675
#
# For k = 101
# Train Data Accuracy: 0.3065326633165829
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 106
# Train Data Accuracy: 0.30904522613065327
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 111
# Train Data Accuracy: 0.3015075376884422
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 116
# Train Data Accuracy: 0.2864321608040201
#
# Test Data Accuracy: 0.3564356435643564
#
# For k = 121
# Train Data Accuracy: 0.2814070351758794
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 126
# Train Data Accuracy: 0.29396984924623115
#
# Test Data Accuracy: 0.37623762376237624
#
# For k = 131
# Train Data Accuracy: 0.27638190954773867
#
# Test Data Accuracy: 0.36633663366336633
#
# For k = 136
# Train Data Accuracy: 0.2889447236180904
#
# Test Data Accuracy: 0.3564356435643564
#
# For k = 141
# Train Data Accuracy: 0.27889447236180903
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 146
# Train Data Accuracy: 0.2889447236180904
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 151
# Train Data Accuracy: 0.30402010050251255
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 156
# Train Data Accuracy: 0.28391959798994976
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 161
# Train Data Accuracy: 0.271356783919598
#
# Test Data Accuracy: 0.32673267326732675
#
# For k = 166
# Train Data Accuracy: 0.2814070351758794
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 171
# Train Data Accuracy: 0.2889447236180904
#
# Test Data Accuracy: 0.32673267326732675
#
# For k = 176
# Train Data Accuracy: 0.2889447236180904
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 181
# Train Data Accuracy: 0.29396984924623115
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 186
# Train Data Accuracy: 0.29396984924623115
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 191
# Train Data Accuracy: 0.28391959798994976
#
# Test Data Accuracy: 0.2871287128712871
#
# For k = 196
# Train Data Accuracy: 0.2914572864321608
#
# Test Data Accuracy: 0.31683168316831684
#
# For k = 201
# Train Data Accuracy: 0.27889447236180903
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 206
# Train Data Accuracy: 0.27889447236180903
#
# Test Data Accuracy: 0.3069306930693069
#
# For k = 211
# Train Data Accuracy: 0.29396984924623115
#
# Test Data Accuracy: 0.297029702970297
#
# For k = 216
# Train Data Accuracy: 0.2964824120603015
#
# Test Data Accuracy: 0.31683168316831684
#
# For k = 221
# Train Data Accuracy: 0.27386934673366836
#
# Test Data Accuracy: 0.3465346534653465
#
# For k = 226
# Train Data Accuracy: 0.271356783919598
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 231
# Train Data Accuracy: 0.27889447236180903
#
# Test Data Accuracy: 0.32673267326732675
#
# For k = 236
# Train Data Accuracy: 0.28391959798994976
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 241
# Train Data Accuracy: 0.30402010050251255
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 246
# Train Data Accuracy: 0.2989949748743719
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 251
# Train Data Accuracy: 0.3015075376884422
#
# Test Data Accuracy: 0.31683168316831684
#
# For k = 256
# Train Data Accuracy: 0.31909547738693467
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 261
# Train Data Accuracy: 0.30402010050251255
#
# Test Data Accuracy: 0.3564356435643564
#
# For k = 266
# Train Data Accuracy: 0.2864321608040201
#
# Test Data Accuracy: 0.36633663366336633
#
# For k = 271
# Train Data Accuracy: 0.2638190954773869
#
# Test Data Accuracy: 0.38613861386138615
#
# For k = 276
# Train Data Accuracy: 0.2562814070351759
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 281
# Train Data Accuracy: 0.2613065326633166
#
# Test Data Accuracy: 0.33663366336633666
#
# For k = 286
# Train Data Accuracy: 0.2562814070351759
#
# Test Data Accuracy: 0.25742574257425743
#
# For k = 291
# Train Data Accuracy: 0.2537688442211055
#
# Test Data Accuracy: 0.26732673267326734
#
# For k = 296
# Train Data Accuracy: 0.2236180904522613
#
# Test Data Accuracy: 0.26732673267326734
#
# For k = 301
# Train Data Accuracy: 0.2236180904522613
#
# Test Data Accuracy: 0.24752475247524752
#
# For k = 306
# Train Data Accuracy: 0.22613065326633167
#
# Test Data Accuracy: 0.24752475247524752
#
# For k = 311
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2376237623762376
#
# For k = 316
# Train Data Accuracy: 0.2135678391959799
#
# Test Data Accuracy: 0.21782178217821782
#
# For k = 321
# Train Data Accuracy: 0.21105527638190955
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 326
# Train Data Accuracy: 0.20351758793969849
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 331
# Train Data Accuracy: 0.20351758793969849
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 336
# Train Data Accuracy: 0.1984924623115578
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 341
# Train Data Accuracy: 0.20351758793969849
#
# Test Data Accuracy: 0.19801980198019803
#
# For k = 346
# Train Data Accuracy: 0.20351758793969849
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 351
# Train Data Accuracy: 0.20351758793969849
#
# Test Data Accuracy: 0.21782178217821782
#
# For k = 356
# Train Data Accuracy: 0.20603015075376885
#
# Test Data Accuracy: 0.21782178217821782
#
# For k = 361
# Train Data Accuracy: 0.20603015075376885
#
# Test Data Accuracy: 0.21782178217821782
#
# For k = 366
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 371
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 376
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 381
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 386
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2079207920792079
#
# For k = 391
# Train Data Accuracy: 0.20854271356783918
#
# Test Data Accuracy: 0.2079207920792079
#
# 0.40594059405940597

# %% [markdown]
# # CNN

# %%
train_data = image_dataset_from_directory(
    data_dir,
    batch_size=32,
    image_size=(256, 256),
    validation_split=0.2,
    subset='training',
    seed=42
)
# Out:
# Found 499 files belonging to 5 classes.
# Using 400 files for training.

# %%
val_data = image_dataset_from_directory(
    data_dir,
    batch_size=32,
    image_size=(256,256),
    validation_split=0.2,
    subset='validation',
    seed=42
)
# Out:
# Found 499 files belonging to 5 classes.
# Using 99 files for validation.

# %%
model = Sequential()

model.add(Rescaling(1./255))
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(5))

model.compile('adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_data,
    validation_data=val_data,
    epochs=20
)
# Out:
# Epoch 1/20

# %%
img = cv2.cvtColor(cv2.resize(cv2.imread('bestpizza.jpg'), (256, 256)), cv2.COLOR_BGR2RGB)/255.0
plt.imshow(img)
plt.show()
img = np.expand_dims(img, axis=0)

# %%
predictions = model.predict(img)

# %%
class_labels = train_data.class_names
predicted_class_index = np.argmax(predictions)
class_labels[predicted_class_index]
